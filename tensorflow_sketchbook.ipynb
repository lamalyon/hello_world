# %% [markdown]
# <a href="https://colab.research.google.com/github/lamalyon/hello_world/blob/readme_edits/tensorflow_sketchbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.Input(shape=(16,)))

# %%
vars(model)
# Out:
# {'_activity_regularizer': None,
#  '_auto_track_sub_layers': False,
#  '_autocast': False,
#  '_base_model_initialized': True,
#  '_build_input_shape': TensorShape([None, 16]),
#  '_callable_losses': [],
#  '_compiled_trainable_state': <WeakKeyDictionary at 0x7fa529a9b668>,
#  '_compute_dtype_object': tf.float32,
#  '_compute_output_and_mask_jointly': True,
#  '_created_nodes': set(),
#  '_default_training_arg': None,
#  '_distribution_strategy': None,
#  '_dtype_defaulted_to_floatx': True,
#  '_dtype_policy': <Policy "float32", loss_scale=None>,
#  '_dynamic': False,
#  '_enable_dict_to_input_mapping': True,
#  '_expects_mask_arg': True,
#  '_expects_training_arg': True,
#  '_feed_input_names': ['input_1'],
#  '_feed_input_shapes': [(None, 16)],
#  '_feed_inputs': [<tf.Tensor 'input_1:0' shape=(None, 16) dtype=float32>],
#  '_graph_initialized': True,
#  '_has_explicit_input_shape': True,
#  '_inbound_nodes': [],
#  '_inferred_input_shape': None,
#  '_initial_weights': None,
# ...

# %%
model.add(tf.keras.layers.Dense(32, activation='relu'))

# %%
vars(model)
# Out:
# {'_activity_regularizer': None,
#  '_auto_track_sub_layers': False,
#  '_autocast': False,
#  '_base_model_initialized': True,
#  '_build_input_shape': TensorShape([None, 16]),
#  '_callable_losses': [],
#  '_compiled_trainable_state': <WeakKeyDictionary at 0x7fa529a9b668>,
#  '_compute_dtype_object': tf.float32,
#  '_compute_output_and_mask_jointly': True,
#  '_created_nodes': set(),
#  '_default_training_arg': None,
#  '_distribution_strategy': None,
#  '_dtype_defaulted_to_floatx': True,
#  '_dtype_policy': <Policy "float32", loss_scale=None>,
#  '_dynamic': False,
#  '_enable_dict_to_input_mapping': True,
#  '_expects_mask_arg': True,
#  '_expects_training_arg': True,
#  '_feed_input_names': ['input_1'],
#  '_feed_input_shapes': [(None, 16)],
#  '_feed_inputs': [<tf.Tensor 'input_1:0' shape=(None, 16) dtype=float32>],
#  '_graph_initialized': True,
#  '_has_explicit_input_shape': True,
#  '_inbound_nodes': [],
#  '_inferred_input_shape': None,
#  '_initial_weights': None,
# ...

# %%
model.add(tf.keras.layers.Dense(32))

# %%
model = tf.keras.Sequential(layers.Dense(8,input_shape=(16,)),
                            layers.Dense(4))

# %%
vars(model)
# Out:
# {'_activity_regularizer': None,
#  '_auto_track_sub_layers': False,
#  '_autocast': False,
#  '_base_model_initialized': True,
#  '_build_input_shape': TensorShape([None, 16]),
#  '_callable_losses': [],
#  '_compiled_trainable_state': <WeakKeyDictionary at 0x7fa529aaa208>,
#  '_compute_dtype_object': tf.float32,
#  '_compute_output_and_mask_jointly': True,
#  '_created_nodes': set(),
#  '_default_training_arg': None,
#  '_distribution_strategy': None,
#  '_dtype_defaulted_to_floatx': True,
#  '_dtype_policy': <Policy "float32", loss_scale=None>,
#  '_dynamic': False,
#  '_enable_dict_to_input_mapping': True,
#  '_expects_mask_arg': True,
#  '_expects_training_arg': True,
#  '_feed_input_names': ['dense_2_input'],
#  '_feed_input_shapes': [(None, 16)],
#  '_feed_inputs': [<tf.Tensor 'dense_2_input:0' shape=(None, 16) dtype=float32>],
#  '_graph_initialized': True,
#  '_has_explicit_input_shape': True,
#  '_inbound_nodes': [],
#  '_inferred_input_shape': None,
# ...

# %%
model = keras.Sequential([layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
xs= np.array([-1,0,1,2,3,4], dtype=float)
xy=np.array([-3,-1,1,3,5,7], dtype=float)

# %%
model.fit(xs,xy,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8400
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7838
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7371
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6979
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6646
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6360
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6112
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5894
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5700
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5526
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5368
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5222
# ...

# %%
print(model.predict([10]))
# Out:
# [[18.986862]]
